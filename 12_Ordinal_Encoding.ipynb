# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("customer.csv")

# %%
df.sample(3)
# Out:
#     age gender   review education purchased
# 28   48   Male     Poor    School        No
# 32   92   Male  Average        UG       Yes
# 16   59   Male     Poor        UG       Yes

# %% [raw]
# From the above dataset preview one can say that , gender (nominal) , review (ordinal) ,education (ordinal) and purchased (nominal) are all categorical cols.
#
# o/p col is also categorical -> Classification problem

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df.iloc[:,0:2] , df.iloc[:,:-1] , test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
#      review education
# 45     Poor        PG
# 2      Good        PG
# 42     Good        PG
# 14     Poor        PG
# 49     Good        UG
# 21  Average        PG
# 28     Poor    School
# 48     Good        UG
# 34  Average    School
# 6      Good    School
# 24  Average        PG
# 4   Average        UG
# 7      Poor    School
# 43     Poor        PG
# 32  Average        UG
# 16     Poor        UG
# 19     Poor        PG
# 5   Average    School
# 13  Average    School
# 1      Poor        UG
# 10     Good        UG
# 30  Average        UG
# 33     Good        PG
# 12     Poor    School
# 9      Good        UG
# 27     Poor        PG
# 8   Average        UG
# 25     Good    School
# 15     Poor        UG
# 29  Average        UG
# 39     Poor        PG
# 18     Good    School
# 44  Average        UG
# 36     Good        UG
# 47     Good        PG
# 31     Poor    School
# 23     Good    School
# 20  Average    School
# 11     Good        UG
# 40     Good    School

# %%
y_train
# Out:
#      review education
# 38     Good    School
# 43     Poor        PG
# 10     Good        UG
# 1      Poor        UG
# 35     Poor    School
# 13  Average    School
# 34  Average    School
# 21  Average        PG
# 17     Poor        UG
# 29  Average        UG
# 46     Poor        PG
# 5   Average    School
# 23     Good    School
# 28     Poor    School
# 31     Poor    School
# 20  Average    School
# 6      Good    School
# 27     Poor        PG
# 26     Poor        PG
# 24  Average        PG
# 19     Poor        PG
# 22     Poor        PG
# 8   Average        UG
# 36     Good        UG
# 11     Good        UG
# 12     Poor    School
# 18     Good    School
# 7      Poor    School
# 40     Good    School
# 49     Good        UG
# 32  Average        UG
# 16     Poor        UG
# 44  Average        UG
# 3      Good        PG
# 2      Good        PG
# 48     Good        UG
# 15     Poor        UG
# 39     Poor        PG
# 30  Average        UG
# 41     Good        PG

# %%
# object of ordinal encoder class
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
X_train = oe.transform(X_train)
X_test = oe.transform(X_test)

# %%
X_train
# Out:
# array([[0., 2.],
#        [2., 2.],
#        [2., 2.],
#        [0., 2.],
#        [2., 1.],
#        [1., 2.],
#        [0., 0.],
#        [2., 1.],
#        [1., 0.],
#        [2., 0.],
#        [1., 2.],
#        [1., 1.],
#        [0., 0.],
#        [0., 2.],
#        [1., 1.],
#        [0., 1.],
#        [0., 2.],
#        [1., 0.],
#        [1., 0.],
#        [0., 1.],
#        [2., 1.],
#        [1., 1.],
#        [2., 2.],
#        [0., 0.],
#        [2., 1.],
#        [0., 2.],
#        [1., 1.],
#        [2., 0.],
#        [0., 1.],
#        [1., 1.],
#        [0., 2.],
#        [2., 0.],
#        [1., 1.],
#        [2., 1.],
#        [2., 2.],
#        [0., 0.],
#        [2., 0.],
#        [1., 0.],
#        [2., 1.],
#        [2., 0.]])

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(y_train[:,''])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 le.fit(y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:93, in LabelEncoder.fit(self, y)
#      80 def fit(self, y):
#      81     """Fit label encoder.
#      82
#      83     Parameters
#    (...)     91         Fitted label encoder.
#      92     """
# ---> 93     y = column_or_1d(y, warn=True)
#      94     self.classes_ = _unique(y)
#      95     return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1483, in column_or_1d(y, dtype, warn, device)
#    1470         warnings.warn(
#    1471             (
#    1472                 "A column-vector y was passed when a 1d array was"
#    (...)   1477             stacklevel=2,
#    1478         )
#    1479     return _asarray_with_order(
# ...

# %%
y_train
# Out:
#      review education
# 45     Poor        PG
# 2      Good        PG
# 42     Good        PG
# 14     Poor        PG
# 49     Good        UG
# 21  Average        PG
# 28     Poor    School
# 48     Good        UG
# 34  Average    School
# 6      Good    School
# 24  Average        PG
# 4   Average        UG
# 7      Poor    School
# 43     Poor        PG
# 32  Average        UG
# 16     Poor        UG
# 19     Poor        PG
# 5   Average    School
# 13  Average    School
# 1      Poor        UG
# 10     Good        UG
# 30  Average        UG
# 33     Good        PG
# 12     Poor    School
# 9      Good        UG
# 27     Poor        PG
# 8   Average        UG
# 25     Good    School
# 15     Poor        UG
# 29  Average        UG
# 39     Poor        PG
# 18     Good    School
# 44  Average        UG
# 36     Good        UG
# 47     Good        PG
# 31     Poor    School
# 23     Good    School
# 20  Average    School
# 11     Good        UG
# 40     Good    School

# %% [raw]
# Label encoding to be redone once you learn Scikit learn as the train test split fn is not
# allocating y_train a single col
