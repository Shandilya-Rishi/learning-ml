# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# #Hello

# %% [markdown]
# ##Sub heading

# %%
#pandas
import pandas as pd

# %%
#df stands for data frame
df = pd.read_csv('crypto50_combined.csv')
